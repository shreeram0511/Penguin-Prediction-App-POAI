# %% [markdown]
# #**Palmer Station (Antarctica) penguins classification using Machine Learning**

# %% [markdown]
# **WEB APP THAT ALLOWS RECOGNITION OF INDIVIDUAL PENGUIN SPECIES COULD AID IN CONSERVATION**

# %% [markdown]
# **Project Mentor** : MANIKANDAN J (ASSISTANT PROFESSOR)
#
# This App **Designed By** SHREERAM.S and SANTHOSH KUMAR D.V

# %% [markdown]
# #**Data Exploration**

# %% [markdown]
# The rigorous study was conducted in the islands of the Palmer Archipelago, Antarctica. These data were collected from 2007 to 2009 by Dr. Kristen Gorman with the Palmer Station Long Term Ecological Research Program, part of the US Long Term Ecological Research Network.

# %% [markdown]
# Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import imp
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('https://raw.githubusercontent.com/shreeram0511/Penguin-Prediction-App-POAI/main/penguins_dataset.csv')
dfc = df.copy() #we keep a copy in case we need the original data set
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7                181
# 1  Adelie  Torgersen            39.5           17.4                186
# 2  Adelie  Torgersen            40.3           18.0                195
# 3  Adelie  Torgersen            36.7           19.3                193
# 4  Adelie  Torgersen            39.3           20.6                190
#
#    body_mass_g     sex
# 0         3750    male
# 1         3800  female
# 2         3250  female
# 3         3450  female
# 4         3650    male

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Dataset statistics**

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    int64
#  5   body_mass_g        333 non-null    int64
#  6   sex                333 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 18.3+ KB

# %% [markdown]
# Checking each object’s columns

# %%
for col in df.select_dtypes(include='object').columns:
    print(df[col].value_counts())
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: island, dtype: int64
# male      168
# female    165
# Name: sex, dtype: int64

# %% [markdown]
# Checking all the Null Values

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# #**Data Visualization**

# %%
penguins = pd.read_csv('https://raw.githubusercontent.com/shreeram0511/Penguin-Prediction-App-POAI/main/penguins_dataset.csv')
# Retrieve column names
list(penguins.columns)
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
# Return the first part of the dataset
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7                181
# 1  Adelie  Torgersen            39.5           17.4                186
# 2  Adelie  Torgersen            40.3           18.0                195
# 3  Adelie  Torgersen            36.7           19.3                193
# 4  Adelie  Torgersen            39.3           20.6                190
#
#    body_mass_g     sex
# 0         3750    male
# 1         3800  female
# 2         3250  female
# 3         3450  female
# 4         3650    male

# %% [markdown]
# **Matplotlib package**
#
# Matplotlib is mainly deployed for basic plotting. Visualization using Matplotlib generally consists of bars, pies, lines, scatter plots and so on.

# %%
# Import matplotlib to make statistical graphics. 
# By convention, it is imported with the shorthand sns.
import matplotlib.pyplot as plt

colors = {'Adelie':'blue', 'Gentoo':'orange', 'Chinstrap':'green'}
plt.scatter(penguins.flipper_length_mm,
penguins.body_mass_g, 
c= penguins.species.apply(lambda x: colors[x]))
plt.xlabel('Flipper Length')
plt.ylabel('Body Mass')
# Out:
# Text(0, 0.5, 'Body Mass')

# %%
import matplotlib.pyplot as plt

colors = {'Adelie':'blue', 'Gentoo':'orange', 'Chinstrap':'green'}
plt.scatter(penguins.bill_length_mm,
penguins.bill_depth_mm, 
c= penguins.species.apply(lambda x: colors[x]))
plt.xlabel('Bill Length')
plt.ylabel('Bill Depth')
# Out:
# Text(0, 0.5, 'Bill Depth')

# %% [markdown]
# **Seaborn Package**
#
# Seaborn is an easy-to-use high level statistical plotting library which provides a variety of visualization patterns. It uses fewer syntax and has easily interesting default themes.
#
# It tries to provide a ‘grammar of graphics’ style way to create plots but in a pythonic style without getting the exact syntax from ggplot as in plotnine.

# %%
# Import seaborn to make statistical graphics. 
# By convention, it is imported with the shorthand sns.
import seaborn as sns 
#load functions in palmerpenguins package

penguins = pd.read_csv('https://raw.githubusercontent.com/shreeram0511/Penguin-Prediction-App-POAI/main/penguins_dataset.csv')
# Apply the default theme
sns.set_theme()
# sns.set_style('whitegrid')
p = sns.relplot(x = 'flipper_length_mm',
            y ='body_mass_g',
            hue = 'species',
            style = 'species',
            data = penguins)
p.set_xlabels('Flipper Length')
p.set_ylabels('Body Mass')

# %%
# Import seaborn to make statistical graphics. 
# By convention, it is imported with the shorthand sns.
import seaborn as sns 
#load functions in palmerpenguins package

penguins = pd.read_csv('https://raw.githubusercontent.com/shreeram0511/Penguin-Prediction-App-POAI/main/penguins_dataset.csv')
# Apply the default theme
sns.set_theme()
# sns.set_style('whitegrid')
p = sns.relplot(x = 'bill_length_mm',
            y ='bill_depth_mm',
            hue = 'species',
            style = 'species',
            data = penguins)
p.set_xlabels('Bill Length')
p.set_ylabels('Bill Depth')

# %% [markdown]
# **Plotnine package**
#
#
# plotnine is an implementation of a grammar of graphics in Python, it is based on ggplot2. The grammar allows users to compose plots by explicitly mapping data to the visual objects that make up the plot.
#
# Plotting with a grammar is powerful, it makes custom (and otherwise complex) plots are easy to think about and then create, while the simple plots remain simple.

# %%
from plotnine import *
# unlike in R, now all the variables must be enclosed by single quotes
(ggplot(penguins) +
  geom_point(aes(x = 'flipper_length_mm',
                  y = 'body_mass_g',
                  color = 'species',
                  shape = 'species')) +
  xlab("Flipper Length")+
  ylab("Body Mass"))
# Out:
# <ggplot: (8774204926253)>

# %%
from plotnine import *
# unlike in R, now all the variables must be enclosed by single quotes
(ggplot(penguins) +
  geom_point(aes(x = 'bill_length_mm',
            y ='bill_depth_mm',
                  color = 'species',
                  shape = 'species')) +
  xlab("Bill Length")+
  ylab("Bill  Depth"))
# Out:
# <ggplot: (8774228819285)>

# %% [markdown]
# #**Model Building**

# %% [markdown]
# Reads the cleaned penguins dataset from CSV file and assigning it to the penguins variable.Perform ordinal feature encoding on the 3 qualitative variables comprising of the target Y variable (species) and the 2 X variables (sex and island).Separates the df dataframe to X and Y matrices.Trains a random forest model.Saves the trained random forest model to a pickled file called penguins_clf.pkl.

# %% [markdown]
# **Before performing ordinal feature encoding**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **After performing ordinal feature encoding.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
# Ordinal feature encoding
df = penguins.copy()
target = 'species'
encode = ['sex','island']

for col in encode:
    dummy = pd.get_dummies(df[col], prefix=col)
    df = pd.concat([df,dummy], axis=1)
    del df[col]

target_mapper = {'Adelie':0, 'Chinstrap':1, 'Gentoo':2}
def target_encode(val):
    return target_mapper[val]

df[target] = df[target].apply(target_encode)

# Separating X and Y
X = df.drop(target, axis=1)
Y = df[target]

# Build random forest model
from sklearn.ensemble import RandomForestClassifier
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,stratify=Y,random_state=25)
model = RandomForestClassifier()
model.fit(X_train,Y_train)

# Saving the model
import pickle
pickle.dump(model, open('penguins_clf.pkl', 'wb'))

# Calculating Test accuracy
X_prediction=model.predict(X_test)

accuracy = accuracy_score(X_prediction,Y_test)
print(accuracy*100,'%')
# Out:
# 97.76119402985076 %
